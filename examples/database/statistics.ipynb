# %%
import os
import pickle
import shutil
import gc
import bisect
import copy
import time
from tqdm import tqdm
from collections import defaultdict, Counter
from aser.database.base import SqliteDBConnection, MongoDBConnection
from aser.database.kg_connection import CHUNKSIZE
from aser.database.kg_connection import EVENTUALITY_TABLE_NAME, EVENTUALITY_COLUMNS, EVENTUALITY_COLUMN_TYPES
from aser.database.kg_connection import RELATION_TABLE_NAME, RELATION_COLUMNS, RELATION_COLUMN_TYPES
from aser.concept.concept_extractor import ASERConceptExtractor
from aser.concept.concept_connection import ASERConceptConnection, CONCEPT_TABLE_NAME, CONCEPT_COLUMNS, CONCEPT_COLUMN_TYPES
from aser.eventuality import Eventuality
from aser.relation import Relation, relation_senses

# %%
datasets = ["yelp", "nyt", "wikipedia", "reddit", "subtitles", "gutenberg"]
select_eventualities = "SELECT %s FROM %s;" % (",".join(["_id", "pattern", "frequency"]), EVENTUALITY_TABLE_NAME)
select_relations = "SELECT %s FROM %s;" % (",".join(["_id"] + relation_senses), RELATION_TABLE_NAME)
select_concepts = "SELECT %s FROM %s;" % (",".join(["_id", "pattern", "info"]), CONCEPT_TABLE_NAME)

# %% [markdown]
# ### Data Statistics

# %%
import json
import os
from multiprocessing import Pool

def iter_files(path):
    """Walk through all files located under a root path."""
    if os.path.isfile(path):
        yield path
    elif os.path.isdir(path):
        for dirpath, _, filenames in os.walk(path):
            for f in filenames:
                yield os.path.join(dirpath, f)
    else:
        raise RuntimeError('Path %s is invalid' % path)
        
def get_cnt(filename):
    sent_cnt, token_cnt = 0, 0
    with open(filename, "r") as f:
        line = f.readline()
        for line in f:
            line = json.loads(line)
            sent_cnt += 1
            token_cnt += len(line["tokens"])
    return sent_cnt, token_cnt

def get_cnt_parallel(filenames):
    sent_cnt, token_cnt = 0, 0
    with Pool(os.cpu_count()-2) as pool:
        results = list()
        for filename in filenames:
            results.append(pool.apply_async(get_cnt, args=(filename,)))
        pool.close()
        for x in results:
            x = x.get()
            sent_cnt += x[0]
            token_cnt += x[1]
    
    return sent_cnt, token_cnt

# %%
totoal_file_cnt, total_sent_cnt, total_token_cnt = 0, 0, 0
for data in datasets:
    data_path = "/home/data/corpora/aser/data/%s/parsed_para/" % (data)
    print(data_path)
    
    files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(data_path)))
    sent_cnt, token_cnt = get_cnt_parallel(files)
    
    totoal_file_cnt += file_cnt
    total_sent_cnt += sent_cnt
    total_token_cnt += token_cnt
    
    print("# number files", len(files))
    print("# number sentences", sent_cnt)
    print("# number tokens", token_cnt)

# %%
nyt_path = "/home/data/corpora/aser/data/nyt/parsed_para/"

nyt_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(nyt_path)))

nyt_sent_cnt, nyt_token_cnt = get_cnt_parallel(nyt_files)

print("# number files", len(nyt_files))
print("# number sentences", nyt_sent_cnt)
print("# number tokens", nyt_token_cnt)
# Out:
# # number files 1827496
# # number sentences 49813108
# # number tokens 1179368352

# %%
yelp_path = "/home/data/corpora/aser/data/yelp/parsed_para/"

yelp_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(yelp_path)))

yelp_sent_cnt, yelp_token_cnt = get_cnt_parallel(yelp_files)

print("# number files", len(yelp_files))
print("# number sentences", yelp_sent_cnt)
print("# number tokens", yelp_token_cnt)
# Out:
# # number files 2224
# # number sentences 54484346
# # number tokens 838760304

# %%
wikipedia_path = "/home/data/corpora/aser/data/wikipedia/parsed_para/"

wikipedia_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(wikipedia_path)))

wikipedia_sent_cnt, wikipedia_token_cnt = get_cnt_parallel(wikipedia_files)

print("# number files", len(wikipedia_files))
print("# number sentences", wikipedia_sent_cnt)
print("# number tokens", wikipedia_token_cnt)
# Out:
# # number files 5620161
# # number sentences 110612107
# # number tokens 2435386651

# %%
reddit_path = "/home/data/corpora/aser/data/reddit/parsed_para/"

reddit_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(reddit_path)))

reddit_sent_cnt, reddit_token_cnt = get_cnt_parallel(reddit_files)

print("# number files", len(reddit_files))
print("# number sentences", reddit_sent_cnt)
print("# number tokens", reddit_token_cnt)
# Out:
# # number files 994
# # number sentences 253633883
# # number tokens 3371328232

# %%
gutenberg_path = "/home/data/corpora/aser/data/gutenberg/parsed_para/"

gutenberg_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(gutenberg_path)))

gutenberg_sent_cnt, gutenberg_token_cnt = get_cnt_parallel(gutenberg_files)

print("# number files", len(gutenberg_files))
print("# number sentences", gutenberg_sent_cnt)
print("# number tokens", gutenberg_token_cnt)
# Out:
# # number files 187350
# # number sentences 210630737
# # number tokens 3610017037

# %%
subtitles_path = "/home/data/corpora/aser/data/subtitles/parsed_para/"

subtitles_files = list(filter(lambda f: f.endswith(".jsonl"), iter_files(subtitles_path)))

subtitles_sent_cnt, subtitles_token_cnt = get_cnt_parallel(subtitles_files)

print("# number files", len(subtitles_files))
print("# number sentences", subtitles_sent_cnt)
print("# number tokens", subtitles_token_cnt)
# Out:
# # number files 1249
# # number sentences 444562019
# # number tokens 3229353900

# %% [markdown]
# ### Core

# %%
kg_path = "/home/xliucr/ASER/database/core_2.0/all/KG.db"
kg_conn = SqliteDBConnection(kg_path, CHUNKSIZE)

pattern_ctr1 = Counter() # number of eventualities
pattern_ctr2 = Counter() # number of unique eventualities
efreqs = Counter()

for erow in kg_conn._conn.execute(select_eventualities):
    eid, pattern, freq = erow
    efreqs[eid] += freq
    pattern_ctr1[pattern] += freq
    pattern_ctr2[pattern] += 1

print("number of eventualities", sum(efreqs.values()))
print("number of unique eventualities", len(efreqs))
for i, pattern in enumerate(sorted(pattern_ctr1.keys())):
    print("No. %d pattern %s" % (i, pattern))
    print("\tnumber of eventualities", pattern_ctr1[pattern])
    print("\tnumber of unique eventualities", pattern_ctr2[pattern])
    
kg_conn.close()
del kg_conn
gc.collect()
# Out:
# number of eventualities 579123901.0
# number of unique eventualities 52940258
# No. 0 pattern s-be-a
# 	number of eventualities 52068570.0
# 	number of unique eventualities 3733978
# No. 1 pattern s-be-o
# 	number of eventualities 49979659.0
# 	number of unique eventualities 6337042
# No. 2 pattern s-v
# 	number of eventualities 260663083.0
# 	number of unique eventualities 14337769
# No. 3 pattern s-v-a
# 	number of eventualities 5951980.0
# 	number of unique eventualities 752468
# No. 4 pattern s-v-be-a
# 	number of eventualities 1035864.0
# 	number of unique eventualities 123263
# No. 5 pattern s-v-be-o
# 	number of eventualities 909250.0
# 	number of unique eventualities 184298
# No. 6 pattern s-v-o
# 	number of eventualities 139031585.0
# 	number of unique eventualities 18100360
# No. 7 pattern s-v-o-be-a
# 	number of eventualities 100917.0
# 	number of unique eventualities 18793
# No. 8 pattern s-v-o-be-o
# 	number of eventualities 95815.0
# 	number of unique eventualities 22411
# No. 9 pattern s-v-o-o
# 	number of eventualities 2765728.0
# 	number of unique eventualities 460526
# No. 10 pattern s-v-o-v-o
# 	number of eventualities 1462883.0
# 	number of unique eventualities 288326
# No. 11 pattern s-v-o-v-o-o
# 	number of eventualities 40428.0
# 	number of unique eventualities 8499
# No. 12 pattern s-v-v
# 	number of eventualities 14624526.0
# 	number of unique eventualities 1591424
# No. 13 pattern s-v-v-o
# 	number of eventualities 12720497.0
# 	number of unique eventualities 2187577
# No. 14 pattern spass-v
# 	number of eventualities 25935769.0
# 	number of unique eventualities 3498516
# No. 15 pattern spass-v-o
# 	number of eventualities 1677244.0
# 	number of unique eventualities 330229
# No. 16 pattern spass-v-v-o
# 	number of eventualities 46475.0
# 	number of unique eventualities 11738
# No. 17 pattern there-be-o
# 	number of eventualities 10013628.0
# 	number of unique eventualities 953041

# %%
kg_path = "/home/xliucr/ASER/database/core_2.0/all/KG.db"
kg_conn = SqliteDBConnection(kg_path, CHUNKSIZE)

rfreqs = Counter()
relation_ctr1 = Counter() # number of relations
relation_ctr2 = Counter() # number of unique relations
relation_ctr3 = Counter() # number of major relations

for rrow in kg_conn._conn.execute(select_relations):
    sum_freq = 0.0
    max_r, max_freq = -1, -1
    for r, freq in filter(lambda x: x[1] > 0, zip(range(15), rrow[1:])):
        sum_freq += freq
        relation_ctr1[r] += freq
        relation_ctr2[r] += 1
        if freq > max_freq and r != 14:
            max_r, max_freq = r, freq
        elif r == 14 and max_r == -1:
            max_r, max_freq = r, freq
    relation_ctr3[max_r] += 1
    rfreqs[rrow[0]] += sum_freq
    
for r in list(relation_ctr1.keys()):
    relation_ctr1[relation_senses[r]] = relation_ctr1.pop(r)
for r in list(relation_ctr2.keys()):
    relation_ctr2[relation_senses[r]] = relation_ctr2.pop(r)
for r in list(relation_ctr3.keys()):
    relation_ctr3[relation_senses[r]] = relation_ctr3.pop(r)

print("number of relations", sum(rfreqs.values()))
print("number of unique relations", len(rfreqs))
for i, sense in enumerate(relation_senses):
    print("No. %d relation %s" % (i, sense))
    print("\tnumber of relations", relation_ctr1[sense])
    print("\tnumber of unique relations", relation_ctr2[sense])
    print("\tnumber of major relations", relation_ctr3[sense])
    
kg_conn.close()
del kg_conn
gc.collect()
# Out:
# number of relations 187018926.27712885
# number of unique relations 52296498
# No. 0 relation Precedence
# 	number of relations 2662402.502265151
# 	number of unique relations 1790016
# 	number of major relations 1646487
# No. 1 relation Succession
# 	number of relations 886728.4309463338
# 	number of unique relations 663183
# 	number of major relations 617887
# No. 2 relation Synchronous
# 	number of relations 4457023.550430128
# 	number of unique relations 3123042
# 	number of major relations 2993862
# No. 3 relation Reason
# 	number of relations 2466643.582709942
# 	number of unique relations 2205076
# 	number of major relations 2072942
# No. 4 relation Result
# 	number of relations 2422963.728729172
# 	number of unique relations 2012311
# 	number of major relations 1826248
# No. 5 relation Condition
# 	number of relations 5507802.535175915
# 	number of unique relations 3160271
# 	number of major relations 3000772
# No. 6 relation Contrast
# 	number of relations 8097385.8756461255
# 	number of unique relations 8655661
# 	number of major relations 7883031
# No. 7 relation Concession
# 	number of relations 539065.73270079
# 	number of unique relations 477155
# 	number of major relations 390807
# No. 8 relation Conjunction
# 	number of relations 14721843.485070871
# 	number of unique relations 13978907
# 	number of major relations 12491913
# No. 9 relation Instantiation
# 	number of relations 26500.274580492387
# 	number of unique relations 18496
# 	number of major relations 9847
# No. 10 relation Restatement
# 	number of relations 61454.28457352848
# 	number of unique relations 65753
# 	number of major relations 37392
# No. 11 relation ChosenAlternative
# 	number of relations 49294.68189992473
# 	number of unique relations 35406
# 	number of major relations 19883
# No. 12 relation Alternative
# 	number of relations 827686.5047540241
# 	number of unique relations 583174
# 	number of major relations 508378
# No. 13 relation Exception
# 	number of relations 24473.109980760142
# 	number of unique relations 20155
# 	number of major relations 17944
# No. 14 relation Co_Occurrence
# 	number of relations 144267658.0
# 	number of unique relations 49232161
# 	number of major relations 18779105
# 0

# %% [markdown]
# ### Full

# %%
pattern_ctr = {data: Counter() for data in datasets} # pattern counter, number of eventualities
pattern_eids = {data: dict() for data in datasets} # pattern eids, number of unique eventualities

pattern_ctr["overall"] = Counter()
pattern_eids["overall"] = dict()

overall_num_events = 0
overall_eids = set()

select_eventualities = "SELECT %s FROM %s;" % (",".join(["_id", "pattern", "frequency"]), EVENTUALITY_TABLE_NAME)

for data in datasets:
    for kg_path in [
        "/home/data/corpora/aser/database/full_0.3/%s/KG1.db" % (data),
        "/home/data/corpora/aser/database/full_0.3/%s/KG2.db" % (data),
        "/home/data/corpora/aser/database/full_0.3/%s/KG3.db" % (data),
        "/home/data/corpora/aser/database/full_0.3/%s/KG4.db" % (data),]:
        print(kg_path)
        kg_conn = SqliteDBConnection(kg_path, CHUNKSIZE)

        for erow in kg_conn._conn.execute(select_eventualities):
            eid, pattern, frequency = erow
            
            pattern_ctr[data][pattern] += frequency
            
            if pattern not in pattern_eids[data]:
                pattern_eids[data][pattern] = set([eid])
            else:
                pattern_eids[data][pattern].add(eid)

        kg_conn.close()

        del kg_conn
        gc.collect()
    
    print("dataset", data)
    num_events = sum(pattern_ctr[data].values())
    pattern_ctr["overall"].update(pattern_ctr[data])
    overall_num_events += num_events
    print("number of eventualities", num_events)
    num_unique_events = sum([len(pattern_eids[data][pattern]) for pattern in pattern_eids[data]])
    print("number of unique eventualities", num_unique_events)
    for i, pattern in enumerate(sorted(pattern_ctr[data].keys())):
        print("No. %d pattern %s" % (i, pattern))
        print("\tnumber of eventualities", pattern_ctr[data][pattern])
        
        if pattern not in pattern_eids["overall"]:
            pattern_eids["overall"][pattern] = copy.copy(pattern_eids[data][pattern])
        else:
            pattern_eids["overall"][pattern].update(pattern_eids[data][pattern])
        print("\tnumber of unique eventualities", len(pattern_eids[data][pattern]))
    print()
        
print("overall")
print("number of eventualities", overall_num_events)
for pattern in pattern_eids["overall"]:
    overall_eids.update(pattern_eids["overall"][pattern])
print("number of unique eventualities", len(overall_eids))
for i, pattern in enumerate(sorted(pattern_ctr["overall"].keys())):
    print("No. %d pattern %s" % (i, pattern))
    print("\tnumber of eventualities", pattern_ctr["overall"][pattern])
    print("\tnumber of unique eventualities", len(pattern_eids["overall"][pattern]))

# %%
rid2relations = {data: dict() for data in datasets}
sense_ctr = {data: Counter() for data in datasets} # number of relations
unique_sense_ctr = {data: Counter() for data in datasets} # number of unique relations
major_sense_ctr = {data: Counter() for data in datasets} # number of major relations

rid2relations["overall"] = dict()
sense_ctr["overall"] = Counter()
unique_sense_ctr["overall"] = Counter()
major_sense_ctr["overall"] = Counter()
overall_num_relations = 0

for data in datasets:
    for kg_path in [
    "/home/data/corpora/aser/database/full_0.3/%s/KG1.db" % (data),
    "/home/data/corpora/aser/database/full_0.3/%s/KG2.db" % (data),
    "/home/data/corpora/aser/database/full_0.3/%s/KG3.db" % (data),
    "/home/data/corpora/aser/database/full_0.3/%s/KG4.db" % (data),]:
        
        print(kg_path)
        kg_conn = SqliteDBConnection(kg_path, CHUNKSIZE)

    #     for rrow in kg_conn.get_columns(RELATION_TABLE_NAME, ["_id"] + relation_senses):
        for rrow in kg_conn._conn.execute(select_relations):
            rid = rrow[0]
            if rid not in rid2relations[data]:
                rid2relations[data][rid] = list(rrow[1:])
            else:
                relation = rid2relations[data][rid]
                for r, rf in filter(lambda x: x[1] > 0.0, zip(range(15), rrow[1:])):
                    relation[r] += rf

        kg_conn.close()

        del kg_conn
        gc.collect()
    
    for rid, relation in rid2relations[data].items():
        max_r, max_freq = -1, -1
        for r, freq in filter(lambda x: x[1] > 0, zip(range(15), relation)):
            sense_ctr[data][r] += freq
            unique_sense_ctr[data][r] += 1
            if max_freq < freq and r != 14:
                max_r, max_freq = r, freq
            elif r == 14 and max_r is -1:
                max_r, max_freq = r, freq
        major_sense_ctr[data][max_r] += 1
        
        if rid not in rid2relations["overall"]:
            rid2relations["overall"][rid] = copy.copy(relation)
        else:
            for r, freq in filter(lambda x: x[1] > 0, zip(range(15), relation)):
                rid2relations["overall"][rid][r] += freq
            
    num_relations = sum(sense_ctr[data].values())
    overall_num_relations += num_relations
    print("number of relations", num_relations)
    num_unique_relations = sum(unique_sense_ctr[data].values())
    print("number of unique relations", num_unique_relations)
    num_major_relations = len(rid2relations[data])
    print("number of major relations", num_major_relations)

    for r in range(15):
        sense = relation_senses[r]
        print("No. %d sense %s" % (r, sense))
        print("\tnumber of relations", sense_ctr[data][r])
        print("\tnumber of unique relations", unique_sense_ctr[data][r])
        print("\tnumber of major relations", major_sense_ctr[data][r])
    print()
    
for rid, relation in rid2relations["overall"].items():
    max_r, max_freq = -1, -1
    for r, freq in filter(lambda x: x[1] > 0, zip(range(15), relation)):
        sense_ctr["overall"][r] += freq
        unique_sense_ctr["overall"][r] += 1
        if max_freq < freq and r != 14:
            max_r, max_freq = r, freq
        elif r == 14 and max_r == -1:
            max_r, max_freq = r, freq
    major_sense_ctr["overall"][max_r] += 1
    
print("overall")
print("number of relations", overall_num_relations)
overall_num_unique_relations = sum(unique_sense_ctr["overall"].values())
print("number of unique relations", overall_num_unique_relations)
overall_num_major_relations = len(rid2relations["overall"])
print("number of major relations", overall_num_major_relations)

for r in range(15):
    sense = relation_senses[r]
    print("No. %d sense %s" % (r, sense))
    print("\tnumber of relations", sense_ctr["overall"][r])
    print("\tnumber of unique relations", unique_sense_ctr["overall"][r])
    print("\tnumber of major relations", major_sense_ctr["overall"][r])
    
gc.collect()
# Out:
# /home/data/corpora/aser/database/full_0.3/yelp/KG1.db
# /home/data/corpora/aser/database/full_0.3/yelp/KG2.db
# /home/data/corpora/aser/database/full_0.3/yelp/KG3.db
# /home/data/corpora/aser/database/full_0.3/yelp/KG4.db
# number of relations 63056766.999986336
# number of unique relations 73984410
# number of major relations 55590249
# No. 0 sense Precedence
# 	number of relations 530404.9999997587
# 	number of unique relations 1292904
# 	number of major relations 1258669
# No. 1 sense Succession
# 	number of relations 434492.99999983737
# 	number of unique relations 777841
# 	number of major relations 760382
# No. 2 sense Synchronous
# 	number of relations 1390824.999997214
# 	number of unique relations 2265689
# 	number of major relations 2225467
# No. 3 sense Reason
# 	number of relations 786552.0000005767
# 	number of unique relations 1311133
# 	number of major relations 1269853
# No. 4 sense Result
# 	number of relations 966290.0000003658
# 	number of unique relations 2213494
# 	number of major relations 2146827
# No. 5 sense Condition
# 	number of relations 1049623.0000014266
# 	number of unique relations 1539931
# 	number of major relations 1514826
# No. 6 sense Contrast
# 	number of relations 2726929.9999992982
# 	number of unique relations 6148599
# 	number of major relations 5775131
# No. 7 sense Concession
# 	number of relations 281887.000000251
# 	number of unique relations 590747
# 	number of major relations 562757
# No. 8 sense Conjunction
# 	number of relations 5338216.999987666
# 	number of unique relations 10557883
# 	number of major relations 9830086
# No. 9 sense Instantiation
# 	number of relations 9276.000000000398
# 	number of unique relations 34569
# 	number of major relations 33339
# No. 10 sense Restatement
# 	number of relations 115468.9999999888
# 	number of unique relations 354862
# 	number of major relations 327134
# No. 11 sense ChosenAlternative
# 	number of relations 37919.999999993364
# 	number of unique relations 99104
# 	number of major relations 83392
# No. 12 sense Alternative
# 	number of relations 127633.99999997216
# 	number of unique relations 242887
# 	number of major relations 223844
# No. 13 sense Exception
# 	number of relations 8382.999999999834
# 	number of unique relations 12426
# 	number of major relations 11960
# No. 14 sense Co_Occurrence
# 	number of relations 49252863.0
# 	number of unique relations 46542341
# 	number of major relations 29566582
#
# /home/data/corpora/aser/database/full_0.3/nyt/KG1.db
# /home/data/corpora/aser/database/full_0.3/nyt/KG2.db
# /home/data/corpora/aser/database/full_0.3/nyt/KG3.db
# /home/data/corpora/aser/database/full_0.3/nyt/KG4.db
# number of relations 47606674.00000062
# number of unique relations 54160743
# number of major relations 45983300
# No. 0 sense Precedence
# 	number of relations 494299.99999989656
# 	number of unique relations 889964
# 	number of major relations 882973
# No. 1 sense Succession
# 	number of relations 371583.99999993824
# 	number of unique relations 544724
# 	number of major relations 542376
# No. 2 sense Synchronous
# 	number of relations 1287244.9999994603
# 	number of unique relations 1815210
# 	number of major relations 1809464
# No. 3 sense Reason
# 	number of relations 564739.9999997574
# 	number of unique relations 795112
# 	number of major relations 788728
# No. 4 sense Result
# 	number of relations 304965.00000018044
# 	number of unique relations 644354
# 	number of major relations 635042
# No. 5 sense Condition
# 	number of relations 761056.0000004238
# 	number of unique relations 1066329
# 	number of major relations 1058551
# No. 6 sense Contrast
# 	number of relations 2711854.999996639
# 	number of unique relations 5946870
# 	number of major relations 5842336
# No. 7 sense Concession
# 	number of relations 349132.00000004604
# 	number of unique relations 661233
# 	number of major relations 652627
# No. 8 sense Conjunction
# 	number of relations 2990276.000004314
# 	number of unique relations 5743853
# 	number of major relations 5458805
# No. 9 sense Instantiation
# 	number of relations 89915.9999999882
# 	number of unique relations 227869
# 	number of major relations 219889
# No. 10 sense Restatement
# 	number of relations 45648.99999999464
# 	number of unique relations 112036
# 	number of major relations 105934
# No. 11 sense ChosenAlternative
# 	number of relations 41656.99999999798
# 	number of unique relations 82133
# 	number of major relations 78198
# No. 12 sense Alternative
# 	number of relations 120474.9999999839
# 	number of unique relations 204433
# 	number of major relations 197418
# No. 13 sense Exception
# 	number of relations 3400.0000000000173
# 	number of unique relations 4432
# 	number of major relations 4314
# No. 14 sense Co_Occurrence
# 	number of relations 37470424.0
# 	number of unique relations 35422191
# 	number of major relations 27706645
#
# /home/data/corpora/aser/database/full_0.3/wikipedia/KG1.db
# /home/data/corpora/aser/database/full_0.3/wikipedia/KG2.db
# /home/data/corpora/aser/database/full_0.3/wikipedia/KG3.db
# /home/data/corpora/aser/database/full_0.3/wikipedia/KG4.db
# number of relations 52456246.00001404
# number of unique relations 58717906
# number of major relations 47987827
# No. 0 sense Precedence
# 	number of relations 843937.0000002317
# 	number of unique relations 1477852
# 	number of major relations 1469136
# No. 1 sense Succession
# 	number of relations 586145.9999998927
# 	number of unique relations 820119
# 	number of major relations 816633
# No. 2 sense Synchronous
# 	number of relations 1730735.9999960216
# 	number of unique relations 2371282
# 	number of major relations 2363530
# No. 3 sense Reason
# 	number of relations 460676.99999976234
# 	number of unique relations 640382
# 	number of major relations 634517
# No. 4 sense Result
# 	number of relations 456621.99999989173
# 	number of unique relations 883360
# 	number of major relations 868851
# No. 5 sense Condition
# 	number of relations 372758.9999999333
# 	number of unique relations 511993
# 	number of major relations 507176
# No. 6 sense Contrast
# 	number of relations 2685087.99999811
# 	number of unique relations 5035546
# 	number of major relations 4920449
# No. 7 sense Concession
# 	number of relations 367758.99999997026
# 	number of unique relations 579418
# 	number of major relations 571934
# No. 8 sense Conjunction
# 	number of relations 4274085.000020267
# 	number of unique relations 6923326
# 	number of major relations 6625031
# No. 9 sense Instantiation
# 	number of relations 120716.99999998104
# 	number of unique relations 282600
# 	number of major relations 271507
# No. 10 sense Restatement
# 	number of relations 60243.99999999323
# 	number of unique relations 135220
# 	number of major relations 128361
# No. 11 sense ChosenAlternative
# 	number of relations 64892.99999999943
# 	number of unique relations 121096
# 	number of major relations 108589
# No. 12 sense Alternative
# 	number of relations 81206.99999999563
# 	number of unique relations 129531
# 	number of major relations 123785
# No. 13 sense Exception
# 	number of relations 4549.000000000005
# 	number of unique relations 5696
# 	number of major relations 5439
# No. 14 sense Co_Occurrence
# 	number of relations 40346827.0
# 	number of unique relations 38800485
# 	number of major relations 28572889
#
# /home/data/corpora/aser/database/full_0.3/reddit/KG1.db
# /home/data/corpora/aser/database/full_0.3/reddit/KG2.db
# /home/data/corpora/aser/database/full_0.3/reddit/KG3.db
# /home/data/corpora/aser/database/full_0.3/reddit/KG4.db
# number of relations 214453006.0000842
# number of unique relations 242345839
# number of major relations 189357498
# No. 0 sense Precedence
# 	number of relations 1949706.9999902318
# 	number of unique relations 4004327
# 	number of major relations 3900250
# No. 1 sense Succession
# 	number of relations 1035217.0000011186
# 	number of unique relations 1724370
# 	number of major relations 1690563
# No. 2 sense Synchronous
# 	number of relations 3889396.0000296114
# 	number of unique relations 5749208
# 	number of major relations 5670157
# No. 3 sense Reason
# 	number of relations 3265556.0000191126
# 	number of unique relations 5133681
# 	number of major relations 4992952
# No. 4 sense Result
# 	number of relations 3055926.000009585
# 	number of unique relations 6963215
# 	number of major relations 6766186
# No. 5 sense Condition
# 	number of relations 6447932.999954107
# 	number of unique relations 9820594
# 	number of major relations 9645287
# No. 6 sense Contrast
# 	number of relations 8940251.999892665
# 	number of unique relations 21594294
# 	number of major relations 20387577
# No. 7 sense Concession
# 	number of relations 813673.0000000513
# 	number of unique relations 1907185
# 	number of major relations 1817490
# No. 8 sense Conjunction
# 	number of relations 12697518.000187118
# 	number of unique relations 27309614
# 	number of major relations 25069973
# No. 9 sense Instantiation
# 	number of relations 136089.0000000409
# 	number of unique relations 509592
# 	number of major relations 476525
# No. 10 sense Restatement
# 	number of relations 110251.99999998594
# 	number of unique relations 350217
# 	number of major relations 309146
# No. 11 sense ChosenAlternative
# 	number of relations 118571.9999999765
# 	number of unique relations 276566
# 	number of major relations 234198
# No. 12 sense Alternative
# 	number of relations 987194.0000005533
# 	number of unique relations 1975272
# 	number of major relations 1866774
# No. 13 sense Exception
# 	number of relations 35615.99999999877
# 	number of unique relations 56180
# 	number of major relations 53440
# No. 14 sense Co_Occurrence
# 	number of relations 170970105.0
# 	number of unique relations 154971524
# 	number of major relations 106476980
#
# /home/data/corpora/aser/database/full_0.3/subtitles/KG1.db
# /home/data/corpora/aser/database/full_0.3/subtitles/KG2.db
# /home/data/corpora/aser/database/full_0.3/subtitles/KG3.db
# /home/data/corpora/aser/database/full_0.3/subtitles/KG4.db
# number of relations 107221405.99998482
# number of unique relations 39885258
# number of major relations 32879945
# No. 0 sense Precedence
# 	number of relations 1986114.9999993518
# 	number of unique relations 1027046
# 	number of major relations 998863
# No. 1 sense Succession
# 	number of relations 521262.99999998446
# 	number of unique relations 249169
# 	number of major relations 243399
# No. 2 sense Synchronous
# 	number of relations 2441195.9999999185
# 	number of unique relations 1040859
# 	number of major relations 1026413
# No. 3 sense Reason
# 	number of relations 1203175.9999999811
# 	number of unique relations 611118
# 	number of major relations 594234
# No. 4 sense Result
# 	number of relations 1910390.999999112
# 	number of unique relations 1326021
# 	number of major relations 1292892
# No. 5 sense Condition
# 	number of relations 3654208.000001007
# 	number of unique relations 1607389
# 	number of major relations 1581075
# No. 6 sense Contrast
# 	number of relations 5057465.999998437
# 	number of unique relations 3217011
# 	number of major relations 3108122
# No. 7 sense Concession
# 	number of relations 352884.99999999825
# 	number of unique relations 223703
# 	number of major relations 211474
# No. 8 sense Conjunction
# 	number of relations 8187120.999987018
# 	number of unique relations 5277852
# 	number of major relations 4919093
# No. 9 sense Instantiation
# 	number of relations 18503.99999999994
# 	number of unique relations 19034
# 	number of major relations 17306
# No. 10 sense Restatement
# 	number of relations 39505.99999999979
# 	number of unique relations 31169
# 	number of major relations 27357
# No. 11 sense ChosenAlternative
# 	number of relations 35447.99999999995
# 	number of unique relations 20693
# 	number of major relations 16698
# No. 12 sense Alternative
# 	number of relations 459366.99999999796
# 	number of unique relations 242077
# 	number of major relations 231323
# No. 13 sense Exception
# 	number of relations 13421.00000000002
# 	number of unique relations 5751
# 	number of major relations 5415
# No. 14 sense Co_Occurrence
# 	number of relations 81341339.0
# 	number of unique relations 24986366
# 	number of major relations 18606281
#
# /home/data/corpora/aser/database/full_0.3/gutenberg/KG1.db
# /home/data/corpora/aser/database/full_0.3/gutenberg/KG2.db
# /home/data/corpora/aser/database/full_0.3/gutenberg/KG3.db
# /home/data/corpora/aser/database/full_0.3/gutenberg/KG4.db
# number of relations 163826222.00009373
# number of unique relations 183357663
# number of major relations 146244346
# No. 0 sense Precedence
# 	number of relations 2523585.9999971767
# 	number of unique relations 5398569
# 	number of major relations 5308020
# No. 1 sense Succession
# 	number of relations 521927.9999996898
# 	number of unique relations 830951
# 	number of major relations 819150
# No. 2 sense Synchronous
# 	number of relations 4251648.000031456
# 	number of unique relations 6300785
# 	number of major relations 6234789
# No. 3 sense Reason
# 	number of relations 863131.0000007735
# 	number of unique relations 1316117
# 	number of major relations 1279217
# No. 4 sense Result
# 	number of relations 1547316.9999925743
# 	number of unique relations 4154529
# 	number of major relations 4028893
# No. 5 sense Condition
# 	number of relations 2687482.000003473
# 	number of unique relations 3589533
# 	number of major relations 3536966
# No. 6 sense Contrast
# 	number of relations 7233604.99988915
# 	number of unique relations 17627367
# 	number of major relations 17030346
# No. 7 sense Concession
# 	number of relations 813166.0000003752
# 	number of unique relations 1730206
# 	number of major relations 1649651
# No. 8 sense Conjunction
# 	number of relations 12721152.000179285
# 	number of unique relations 26594185
# 	number of major relations 24571551
# No. 9 sense Instantiation
# 	number of relations 67483.99999997982
# 	number of unique relations 205521
# 	number of major relations 189859
# No. 10 sense Restatement
# 	number of relations 128447.99999996892
# 	number of unique relations 321681
# 	number of major relations 293232
# No. 11 sense ChosenAlternative
# 	number of relations 21789.99999999946
# 	number of unique relations 47953
# 	number of major relations 41019
# No. 12 sense Alternative
# 	number of relations 542554.9999998022
# 	number of unique relations 752841
# 	number of major relations 699884
# No. 13 sense Exception
# 	number of relations 16456.000000000564
# 	number of unique relations 21583
# 	number of major relations 20450
# No. 14 sense Co_Occurrence
# 	number of relations 129886474.0
# 	number of unique relations 114465842
# 	number of major relations 80541319
#
# overall
# number of relations 648620321.0001637
# number of unique relations 648514465
# number of major relations 514367233
# No. 0 sense Precedence
# 	number of relations 8328049.999928201
# 	number of unique relations 14058213
# 	number of major relations 13765283
# No. 1 sense Succession
# 	number of relations 3470631.0000093356
# 	number of unique relations 4939291
# 	number of major relations 4856219
# No. 2 sense Synchronous
# 	number of relations 14991046.000148337
# 	number of unique relations 19464898
# 	number of major relations 19230498
# No. 3 sense Reason
# 	number of relations 7143831.999973756
# 	number of unique relations 9775829
# 	number of major relations 9512142
# No. 4 sense Result
# 	number of relations 8241510.999916423
# 	number of unique relations 16153925
# 	number of major relations 15685994
# No. 5 sense Condition
# 	number of relations 14973061.00005102
# 	number of unique relations 18052484
# 	number of major relations 17738386
# No. 6 sense Contrast
# 	number of relations 29355196.000742733
# 	number of unique relations 59333901
# 	number of major relations 56791713
# No. 7 sense Concession
# 	number of relations 2978502.0000077845
# 	number of unique relations 5684395
# 	number of major relations 5447971
# No. 8 sense Conjunction
# 	number of relations 46208369.00487616
# 	number of unique relations 82121343
# 	number of major relations 76163273
# No. 9 sense Instantiation
# 	number of relations 441985.9999999618
# 	number of unique relations 1278381
# 	number of major relations 1206114
# No. 10 sense Restatement
# 	number of relations 499567.9999998585
# 	number of unique relations 1304095
# 	number of major relations 1187653
# No. 11 sense ChosenAlternative
# 	number of relations 320280.00000031886
# 	number of unique relations 647228
# 	number of major relations 560915
# No. 12 sense Alternative
# 	number of relations 2318431.9999991646
# 	number of unique relations 3539892
# 	number of major relations 3329180
# No. 13 sense Exception
# 	number of relations 81824.99999999389
# 	number of unique relations 106000
# 	number of major relations 100700
# No. 14 sense Co_Occurrence
# 	number of relations 509268032.0
# 	number of unique relations 412054590
# 	number of major relations 288791192
# 0
